# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjiGT/Scyther/blob/master/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color='red'>***video link***</font> --> https://youtu.be/2kyjPO0l_E0
#
# <font color='red'>***Logisitc Regression (Conceptual video)***</font> --> https://youtu.be/S4IG2wv9Lnk
#
# #<font color='redr'> ***Logistic Regression : Pima Indians Diabetes***</font>
#
# <font color='orange'>*A tribal group in North America where teenager females are prone to Type-II diabetes.*</font>
#
# More info : https://www.britannica.com/topic/Pima-people
#
# > Pregnancies: Number of times pregnant
#
#
# > Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
#
# > BloodPressure: Diastolic blood pressure (mm Hg)
#
#
# > SkinThickness: Triceps skin fold thickness (mm)
#
#
# > Insulin: 2-Hour serum insulin (mu U/ml)
#
#
# > BMI: Body mass index (weight in kg/(height in m)^2)
#
# > DiabetesPedigreeFunction: Diabetes pedigree function
#
# > Age: Age (years)
#
# > Outcome: Class variable (0 or 1)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("pima-indians-diabetes.csv")
df.columns = ['Pregnancy','Blood_Plasma', 'Diastolic_BP','Skinfolds', 'FAST_test', 'BMI', 'Pediatric', 'Age', 'Class']
df

# %%
df.describe(include='all')

# %%
df.dtypes

# %%
df[~df.applymap(np.isreal).all(1)]

# %%
df['Class'].value_counts()

# %%
sns.pairplot(df, diag_kind='kde', hue='Class')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
X = df.iloc[:,0:8]
X

# %%
Y = np.ravel(df[["Class"]])
Y

# %%
trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
trainX

# %%
trainY

# %%
model = LogisticRegression()
model.fit(trainX, trainY)

# %%
Y_pred = model.predict(testX)
acc = model.score(testX, testY)
acc

# %%
print(pd.DataFrame(metrics.confusion_matrix(testY, Y_pred,labels=[0,1]), index=['true:0','true:1'], columns=['pred:0', 'pred:1'])) #14 values lying on the extreme end

# %% [markdown]
# ![meme-2.jpg](data:image/jpeg;base64,...)
